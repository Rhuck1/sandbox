# %% [markdown]
# ### LSTM Neural Network for Time Series Prediction
#
# https://www.jakob-aungiers.com/articles/a/LSTM-Neural-Network-for-Time-Series-Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.helper_functions import DataLoader, Model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-c1a937a89bf8> in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 from src.helper_functions import DataLoader, Model
#
# ModuleNotFoundError: No module named 'src'

# %%
sinewave = pd.read_csv('https://raw.githubusercontent.com/jaungiers/LSTM-Neural-Network-for-Time-Series-Prediction/master/data/sinewave.csv')
sp500 = pd.read_csv('https://raw.githubusercontent.com/jaungiers/LSTM-Neural-Network-for-Time-Series-Prediction/master/data/sp500.csv')
sinewave.to_csv('/home/bobbyhuck/sandbox/time_series_prediction/data/sinewave.csv', index=False)
sp500.to_csv('/home/bobbyhuck/sandbox/time_series_prediction/data/sp500.csv', index=False)

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax.plot(sinewave);

# %%
data = DataLoader()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1775f7210350> in <module>
# ----> 1 data = DataLoader()
#
# NameError: name 'DataLoader' is not defined
